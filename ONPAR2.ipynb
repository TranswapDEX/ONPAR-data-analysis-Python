# %%
import pandas as pd
import numpy as np
from scipy.stats import spearmanr
from scipy.stats import pearsonr

# %%
codes=pd.read_csv('/Users/blakemyers/Desktop/data/LightEOU_All.csv', sep=',', error_bad_lines=False, encoding='UTF8')

# %%
codes.head(5)
# Out:
#    TotalScore  S02  S03  S05  S06  S08  S10  S02_BottomLoudAmp  S02_incHigh  \
# 0          14    3    1    2    3    3    2                  0            0
# 1          10    1    3    0    1    3    2                  0            1
# 2           4    2    0    1   99    0    1                  1            0
# 3          14    3    3    2    3    1    2                  0            0
# 4           7    3    0    0    2    0    2                  0            0
#
#    S02_incLoud  ...  S10_RCarrow  S10_RCsome  S10_REarrow  S10_RefChair  \
# 0            0  ...            1           1            1             0
# 1            1  ...            1           1            1             1
# 2            1  ...            1           1            0             0
# 3            0  ...            1           1            1             1
# 4            0  ...            0           0            0             1
#
#    S10_Remits  S10_REsome  S10_RLarrow  S10_RLsome  S10_yellow  \
# ...

# %%
ts = codes["TotalScore"]

# %%
codes.replace(99, np.nan)
# Out:
#      TotalScore  S02  S03  S05  S06  S08  S10  S02_BottomLoudAmp  S02_incHigh  \
# 0            14  3.0  1.0  2.0  3.0  3.0  2.0                  0            0
# 1            10  1.0  3.0  0.0  1.0  3.0  2.0                  0            1
# 2             4  2.0  0.0  1.0  NaN  0.0  1.0                  1            0
# 3            14  3.0  3.0  2.0  3.0  1.0  2.0                  0            0
# 4             7  3.0  0.0  0.0  2.0  0.0  2.0                  0            0
# ..          ...  ...  ...  ...  ...  ...  ...                ...          ...
# 887           7  3.0  0.0  2.0  1.0  1.0  0.0                  0            0
# 888          13  3.0  3.0  2.0  2.0  1.0  2.0                  0            0
# 889           6  0.0  0.0  1.0  1.0  2.0  2.0                  0            0
# 890           5  0.0  1.0  0.0  2.0  0.0  2.0                  0            1
# 891          10  3.0  1.0  2.0  1.0  1.0  2.0                  0            0
#
# ...

# %%
ts.head(3)
# Out:
# 0    14
# 1    10
# 2     4
# Name: TotalScore, dtype: int64

# %%
codes.query('((S10_RCarrow==1 and S10_RCsome==1 and S10_REarrow==1) and (S02_incLoud==0 and S02_incHigh==0)) and ((S10_RCarrow!=9 and S10_RCsome!=9 and S10_REarrow!=9) and (S02_incLoud!=9 and S02_incHigh!=9))').shape
# Out:
# (80, 90)

# %%
codes.query('(S10_RCarrow!=9 and S10_RCsome!=9 and S10_REarrow!=9) and (S02_incLoud!=9 and S02_incHigh!=9)').shape
# Out:
# (880, 90)

# %%
print(codes.shape)
# Out:
# (892, 90)

# %%
codes.query('S08_moreLight==1').shape
# Out:
# (242, 90)

# %%
codes.query('S08_moreLight!=9').shape
# Out:
# (885, 90)

# %%
242/885
# Out:
# 0.2734463276836158

# %%
codes.query('S03_WwvLnS ==0 and S03_whiteWwvln1 ==1').shape
# Out:
# (134, 90)

# %%
codes.query('S03_WwvLnS !=9 and S03_whiteWwvln1 !=9').shape
# Out:
# (881, 90)

# %%
134/881
# Out:
# 0.15209988649262202

# %%
ts = codes.query('S03_WwvLnS !=9')
el = ts.apply(lambda x: 1 if x['S03_WwvLnS'] == 0 and x['S03_whiteWwvln1'] == 1 else 0, axis=1)
tss = ts["TotalScore"]
corr, _ = pearsonr(tss, el)
print(corr)
# Out:
# -0.14574565194850309

# %%
codes.query('S03_inconsistentB ==1 and S03_inconsistentG ==1').shape
# Out:
# (101, 90)

# %%
codes.query('S03_inconsistentB !=9 and S03_inconsistentG != 9').shape
# Out:
# (881, 90)

# %%
101/881
# Out:
# 0.11464245175936436

# %%
ts = codes.query('S03_inconsistentB !=9')
el = ts.apply(lambda x: 1 if x['S03_inconsistentB'] == 1 and x['S03_inconsistentG'] == 1 else 0, axis=1)
tss = ts["TotalScore"]
corr, _ = pearsonr(tss, el)
print(corr)
# Out:
# -0.14673965726601018

# %%
codes.query('(S02_LeftLoudAmp + S02_RightLoudAmp + S02_TopLoudAmp + S02_BottomLoudAmp >=2) and (S02_LeftLoudAmp!=9 and S02_RightLoudAmp!=9 and S02_TopLoudAmp!=9 and S02_BottomLoudAmp !=9)').shape
# Out:
# (411, 90)

# %%
codes.query('S02_LeftLoudAmp!=9 and S02_RightLoudAmp!=9 and S02_TopLoudAmp!=9 and S02_BottomLoudAmp !=9').shape
# Out:
# (889, 90)

# %%
411/889
# Out:
# 0.46231721034870643

# %%
ts = codes.query('S02_LeftLoudAmp !=9')
el = ts.apply(lambda x: 1 if x['S02_LeftLoudAmp'] + x['S02_RightLoudAmp'] + x['S02_TopLoudAmp'] + x['S02_BottomLoudAmp'] >=2 else 0, axis=1)
tss = ts["TotalScore"]
corr, _ = pearsonr(tss, el)
print(corr)
# Out:
# -0.44038702994089873

# %%
codes.query('S02_LeftLoudFreq==1').shape
# Out:
# (368, 90)

# %%
codes.query('S02_LeftLoudFreq!=9').shape
# Out:
# (889, 90)

# %%
368/889
# Out:
# 0.41394825646794153

# %%
ts = codes.query('S02_LeftLoudFreq !=9')
el = ts.apply(lambda x: 1 if x['S02_LeftLoudFreq'] == 1 else 0, axis=1)
tss = ts["TotalScore"]
corr, _ = pearsonr(tss, el)
print(corr)
# Out:
# -0.426680976431564

# %%
codes.query('S02_incHigh==1 and S02_incLow==1').shape
# Out:
# (253, 90)

# %%
codes.query('S02_incHigh!=9 and S02_incLow!=9').shape
# Out:
# (889, 90)

# %%
ts = codes.query('S02_incHigh!=9 and S02_incLow!=9')
el = ts.apply(lambda x: 1 if x['S02_incHigh']==1 and x['S02_incLow']==1 else 0, axis=1)
tss = ts["TotalScore"]
corr, _ = pearsonr(tss, el)
print(corr)
# Out:
# -0.41064768176311683

# %%
253/889
# Out:
# 0.2845894263217098

# %%
codes.query('S02_incHigh==1 and S02_incLow==1 and S02_LeftLoudFreq==1').shape
# Out:
# (240, 90)

# %%
240/889
# Out:
# 0.26996625421822273

# %%
ts = codes.query('S02_incHigh!=9')
el = ts.apply(lambda x: 1 if x['S02_incHigh']==1 and x['S02_incLow']==1 and x['S02_LeftLoudFreq'] == 1 else 0, axis=1)
tss = ts["TotalScore"]
corr, _ = pearsonr(tss, el)
print(corr)
# Out:
# -0.38599559072901557

# %%
codes.query('(S03_WcolorS + S03_whiteWc1 + S03_whiteWc2 >=2) and (S03_WcolorS + S03_whiteWc1 + S03_whiteWc2 < 9)').shape
# Out:
# (306, 90)

# %%
codes.query('S03_WcolorS + S03_whiteWc1 + S03_whiteWc2 < 9').shape
# Out:
# (881, 90)

# %%
306/881
# Out:
# 0.3473325766174801

# %%
ts = codes.query('S03_WcolorS!=9')
el = ts.apply(lambda x: 1 if x['S03_WcolorS'] + x['S03_whiteWc1'] + x['S03_whiteWc2'] >=2 else 0, axis=1)
tss = ts["TotalScore"]
corr, _ = pearsonr(tss, el)
print(corr)
# Out:
# -0.30254042990592056

# %%
codes.query('(S03_WwvLnS + S03_inconsistentB + S03_RBwaveLWt + S03_inconsistentG >=2) and (S03_WcolorS + S03_whiteWc1 + S03_whiteWc2 < 9)').shape
# Out:
# (410, 90)

# %%
410/881
# Out:
# 0.46538024971623154

# %%
ts = codes.query('S03_WcolorS!=9')
el = ts.apply(lambda x: 1 if x['S03_WwvLnS'] + x['S03_inconsistentB'] + x['S03_RBwaveLWt'] + x['S03_inconsistentG'] >=2 else 0, axis=1)
tss = ts["TotalScore"]
corr, _ = pearsonr(tss, el)
print(corr)
# Out:
# -0.3479874968230501

# %%
codes.query('(S03_WwvLnS + S03_inconsistentB + S03_RBwaveLWt + S03_inconsistentG >=3) and (S03_WcolorS + S03_whiteWc1 + S03_whiteWc2 < 9)').shape
# Out:
# (93, 90)

# %%
93/991
# Out:
# 0.09384460141271443

# %%
ts = codes.query('S03_WcolorS!=9')
el = ts.apply(lambda x: 1 if x['S03_WwvLnS'] + x['S03_inconsistentB'] + x['S03_RBwaveLWt'] + x['S03_inconsistentG'] >=3 else 0, axis=1)
tss = ts["TotalScore"]
corr, _ = pearsonr(tss, el)
print(corr)
# Out:
# -0.1498389958585866

# %%
codes.query('S03_BcolorW ==1 and S03_TcolorW ==1').shape
# Out:
# (62, 90)

# %%
62/881
# Out:
# 0.07037457434733257

# %%
ts = codes.query('S03_WcolorS!=9')
el = ts.apply(lambda x: 1 if x['S03_BcolorW'] ==1 and x['S03_TcolorW'] ==1 else 0, axis=1)
tss = ts["TotalScore"]
corr, _ = pearsonr(tss, el)
print(corr)
# Out:
# -0.13661863657244586

# %%
codes.query('S05_glassNo + S05_airRefract + S05_glassBend >= 2').shape
# Out:
# (205, 90)

# %%
codes.query('S05_glassNo!=9').shape
# Out:
# (890, 90)

# %%
205/890
# Out:
# 0.2303370786516854

# %%
ts = codes.query('S05_glassNo!=9')
el = ts.apply(lambda x: 1 if x['S05_glassNo'] + x['S05_airRefract'] + x['S05_glassBend'] >= 2 else 0, axis=1)
tss = ts["TotalScore"]
corr, _ = pearsonr(tss, el)
print(corr)
# Out:
# -0.330109238956103

# %%
codes.query('S06_Wsize2 ==1').shape
# Out:
# (644, 90)

# %%
codes.query('S06_Wsize2 !=9').shape
# Out:
# (875, 90)

# %%
644/875
# Out:
# 0.736

# %%
ts = codes.query('S06_Wsize2!=9')
el = ts.apply(lambda x: 1 if x['S06_Wsize2'] ==1 else 0, axis=1)
tss = ts["TotalScore"]
corr, _ = pearsonr(tss, el)
print(corr)
# Out:
# 0.09124700843952345

# %%
codes.query('S06_Wrotate2 ==1').shape
# Out:
# (227, 90)

# %%
227/875
# Out:
# 0.25942857142857145

# %%
ts = codes.query('S06_Wsize2!=9')
el = ts.apply(lambda x: 1 if x['S06_Wrotate2'] ==1 else 0, axis=1)
tss = ts["TotalScore"]
corr, _ = pearsonr(tss, el)
print(corr)
# Out:
# -0.25487418390019445

# %%
codes.query('S06_Wdark2 ==1').shape
# Out:
# (535, 90)

# %%
535/875
# Out:
# 0.6114285714285714

# %%
ts = codes.query('S06_Wsize2!=9')
el = ts.apply(lambda x: 1 if x['S06_Wdark2'] ==1 else 0, axis=1)
tss = ts["TotalScore"]
corr, _ = pearsonr(tss, el)
print(corr)
# Out:
# -0.027628954680354246

# %%
codes.query('S06_shadows ==1').shape
# Out:
# (142, 90)

# %%
142/875
# Out:
# 0.16228571428571428

# %%
ts = codes.query('S06_Wsize2!=9')
el = ts.apply(lambda x: 1 if x['S06_shadows'] ==1 else 0, axis=1)
tss = ts["TotalScore"]
corr, _ = pearsonr(tss, el)
print(corr)
# Out:
# -0.2728247164878707

# %%
codes.query('(S08_rayFilter + S08_rayScreen + S08_raySeat <= 1) and S08_raySeat != 9').shape
# Out:
# (332, 90)

# %%
codes.query('S08_raySeat != 9').shape
# Out:
# (885, 90)

# %%
332/885
# Out:
# 0.3751412429378531

# %%
ts = codes.query('S08_raySeat!=9')
el = ts.apply(lambda x: 1 if x['S08_rayFilter'] + x['S08_rayScreen'] + x['S08_raySeat'] <= 1 else 0, axis=1)
tss = ts["TotalScore"]
corr, _ = pearsonr(tss, el)
print(corr)
# Out:
# -0.4790072712789317

# %%
codes.query('(S08_lumenFilter + S08_lumenScreen + S08_lumenSeats >= 2) and S08_lumenSeats != 9').shape
# Out:
# (647, 90)

# %%
codes.query('S08_lumenSeats != 9').shape
# Out:
# (885, 90)

# %%
647/885
# Out:
# 0.7310734463276836

# %%
ts = codes.query('S08_raySeat!=9')
el = ts.apply(lambda x: 1 if x['S08_lumenFilter'] + x['S08_lumenScreen'] + x['S08_lumenSeats'] >= 2 else 0, axis=1)
tss = ts["TotalScore"]
corr, _ = pearsonr(tss, el)
print(corr)
# Out:
# -0.33238553680448535

# %%
codes.query('(S08_moreLight==1 and S08_lessLight ==1) and S08_lumenSeats != 9').shape
# Out:
# (82, 90)

# %%
82/885
# Out:
# 0.09265536723163842

# %%
ts = codes.query('S08_raySeat!=9')
el = ts.apply(lambda x: 1 if x['S08_moreLight']==1 and + x['S08_lessLight']==1 else 0, axis=1)
tss = ts["TotalScore"]
corr, _ = pearsonr(tss, el)
print(corr)
# Out:
# -0.16245713198554337

# %%
codes.query('(S10_CEsome == 1 and S10_black == 0) and (S10_REsome + S10_BEsome + S10_BCsome + S10_RCsome + S10_BLsome + S10_RLsome == 0) and S10_RCsome != 9').shape
# Out:
# (33, 90)

# %%
codes.query('S10_RCsome != 9').shape
# Out:
# (883, 90)

# %%
33/883
# Out:
# 0.03737259343148358

# %%
ts = codes.query('S10_RCsome!=9')
el = ts.apply(lambda x: 1 if x['S10_CEsome'] == 1 and x['S10_black'] == 0 and (x['S10_REsome'] + x['S10_BEsome'] + x['S10_BCsome'] + x['S10_RCsome'] + x['S10_BLsome'] + x['S10_RLsome'] == 0) else 0, axis=1)
tss = ts["TotalScore"]
corr, _ = pearsonr(tss, el)
print(corr)
# Out:
# -0.08706370150664891

# %%
codes.query('S10_CEsome == 0 and (S10_REsome + S10_BEsome + S10_BCsome + S10_RCsome + S10_BLsome + S10_RLsome == 0) and S10_RCsome != 9').shape
# Out:
# (232, 90)

# %%
232/883
# Out:
# 0.2627406568516421

# %%
ts = codes.query('S10_RCsome!=9')
el = ts.apply(lambda x: 1 if x['S10_CEsome'] == 0 and (x['S10_REsome'] + x['S10_BEsome'] + x['S10_BCsome'] + x['S10_RCsome'] + x['S10_BLsome'] + x['S10_RLsome'] == 0) else 0, axis=1)
tss = ts["TotalScore"]
corr, _ = pearsonr(tss, el)
print(corr)
# Out:
# -0.5125937594547137

# %%
codes.query('S10_black == 1 and (S10_REsome + S10_BEsome + S10_BCsome + S10_RCsome + S10_BLsome + S10_RLsome == 0) and S10_RCsome != 9').shape
# Out:
# (35, 90)

# %%
35/883
# Out:
# 0.039637599093997736

# %%
ts = codes.query('S10_RCsome!=9')
el = ts.apply(lambda x: 1 if x['S10_black'] == 1 and (x['S10_REsome'] + x['S10_BEsome'] + x['S10_BCsome'] + x['S10_RCsome'] + x['S10_BLsome'] + x['S10_RLsome'] == 0) else 0, axis=1)
tss = ts["TotalScore"]
corr, _ = pearsonr(tss, el)
print(corr)
# Out:
# -0.1057368520337575

# %%
codes.query('(S10_BCsome + S10_CEsome + S10_BLsome + S10_BEsome == 4) and (S10_REsome + S10_RCsome + S10_RLsome == 0) and (S10_BEsome + S10_BLsome + S10_BCsome >=0)').shape
# Out:
# (0, 90)

# %%
codes.query('(S10_BCsome + S10_CEsome == 0) and (S10_REsome + S10_RCsome + S10_RLsome == 0) and (S10_BEsome + S10_BLsome + S10_BCsome >=0)').shape
# Out:
# (249, 90)

# %%
249/883
# Out:
# 0.28199320498301245

# %%
ts = codes.query('S10_RCsome!=9')
el = ts.apply(lambda x: 1 if (x['S10_BCsome'] + x['S10_CEsome'] == 0) and (x['S10_REsome'] + x['S10_RCsome'] + x['S10_RLsome'] == 0) and (x['S10_BEsome'] + x['S10_BLsome'] + x['S10_BCsome'] >=0) else 0, axis=1)
tss = ts["TotalScore"]
corr, _ = pearsonr(tss, el)
print(corr)
# Out:
# -0.5281054905494427

# %%
codes.query('(S10_BCsome + S10_CEsome == 1) and (S10_REsome + S10_RCsome + S10_RLsome == 0) and (S10_BEsome + S10_BLsome + S10_BCsome >=0)').shape
# Out:
# (80, 90)

# %%
80/883
# Out:
# 0.09060022650056625

# %%
ts = codes.query('S10_RCsome!=9')
el = ts.apply(lambda x: 1 if (x['S10_BCsome'] + x['S10_CEsome'] == 1) and (x['S10_REsome'] + x['S10_RCsome'] + x['S10_RLsome'] == 0) and (x['S10_BEsome'] + x['S10_BLsome'] + x['S10_BCsome'] >=0) else 0, axis=1)
tss = ts["TotalScore"]
corr, _ = pearsonr(tss, el)
print(corr)
# Out:
# -0.11276852540484508

# %%
codes.query('S10_BLsome == 0 and (S10_REsome + S10_RCsome + S10_RLsome == 0) and (S10_BEsome + S10_BLsome + S10_BCsome >=0)').shape
# Out:
# (323, 90)

# %%
323/883
# Out:
# 0.36579841449603623

# %%
ts = codes.query('S10_RCsome!=9')
el = ts.apply(lambda x: 1 if x['S10_BLsome'] == 0 and (x['S10_REsome'] + x['S10_RCsome'] + x['S10_RLsome'] == 0) and (x['S10_BEsome'] + x['S10_BLsome'] + x['S10_BCsome'] >=0) else 0, axis=1)
tss = ts["TotalScore"]
corr, _ = pearsonr(tss, el)
print(corr)
# Out:
# -0.5427587352378447

# %%
codes.query('S10_BEsome == 0 and (S10_REsome + S10_RCsome + S10_RLsome == 0) and (S10_BEsome + S10_BLsome + S10_BCsome >=0)').shape
# Out:
# (332, 90)

# %%
332/883
# Out:
# 0.37599093997734995

# %%
ts = codes.query('S10_RCsome!=9')
el = ts.apply(lambda x: 1 if x['S10_BEsome'] == 0 and (x['S10_REsome'] + x['S10_RCsome'] + x['S10_RLsome'] == 0) and (x['S10_BEsome'] + x['S10_BLsome'] + x['S10_BCsome'] >=0) else 0, axis=1)
tss = ts["TotalScore"]
corr, _ = pearsonr(tss, el)
print(corr)
# Out:
# -0.5432795969808913

# %%
codes.query('(S10_RCsome + S10_CEsome + S10_RLsome + S10_REsome == 4) and (S10_BEsome + S10_BCsome + S10_BLsome == 0) and (S10_REsome + S10_RLsome + S10_RCsome >=0)').shape
# Out:
# (1, 90)

# %%
1/883
# Out:
# 0.0011325028312570782

# %%
ts = codes.query('S10_RCsome!=9')
el = ts.apply(lambda x: 1 if (x['S10_RCsome'] + x['S10_CEsome'] + x['S10_RLsome'] + x['S10_REsome'] == 4) and (x['S10_BEsome'] + x['S10_BCsome'] + x['S10_BLsome'] == 0) and (x['S10_REsome'] + x['S10_RLsome'] + x['S10_RCsome'] >=0) else 0, axis=1)
tss = ts["TotalScore"]
corr, _ = pearsonr(tss, el)
print(corr)
# Out:
# 0.020320728144627428

# %%
codes.query('(S10_RCsome + S10_CEsome == 0) and (S10_BEsome + S10_BCsome + S10_BLsome == 0) and (S10_REsome + S10_RLsome + S10_RCsome >=0)').shape
# Out:
# (245, 90)

# %%
245/883
# Out:
# 0.27746319365798416

# %%
ts = codes.query('S10_RCsome!=9')
el = ts.apply(lambda x: 1 if (x['S10_RCsome'] + x['S10_CEsome'] == 0) and (x['S10_BEsome'] + x['S10_BCsome'] + x['S10_BLsome'] == 0) and (x['S10_REsome'] + x['S10_RLsome'] + x['S10_RCsome'] >=0) else 0, axis=1)
tss = ts["TotalScore"]
corr, _ = pearsonr(tss, el)
print(corr)
# Out:
# -0.5253524643831502

# %%
codes.query('(S10_RCsome + S10_CEsome == 1) and (S10_BEsome + S10_BCsome + S10_BLsome == 0) and (S10_REsome + S10_RLsome + S10_RCsome >=0)').shape
# Out:
# (79, 90)

# %%
79/883
# Out:
# 0.08946772366930918

# %%
ts = codes.query('S10_RCsome!=9')
el = ts.apply(lambda x: 1 if (x['S10_RCsome'] + x['S10_CEsome'] == 1) and (x['S10_BEsome'] + x['S10_BCsome'] + x['S10_BLsome'] == 0) and (x['S10_REsome'] + x['S10_RLsome'] + x['S10_RCsome'] >=0) else 0, axis=1)
tss = ts["TotalScore"]
corr, _ = pearsonr(tss, el)
print(corr)
# Out:
# -0.09779355496580609

# %%
codes.query('S10_RLsome == 0 and (S10_BEsome + S10_BCsome + S10_BLsome == 0) and (S10_REsome + S10_RLsome + S10_RCsome >=0)').shape
# Out:
# (313, 90)

# %%
313/883
# Out:
# 0.35447338618346547

# %%
ts = codes.query('S10_RCsome!=9')
el = ts.apply(lambda x: 1 if x['S10_RLsome'] == 0 and (x['S10_BEsome'] + x['S10_BCsome'] + x['S10_BLsome'] == 0) and (x['S10_REsome'] + x['S10_RLsome'] + x['S10_RCsome'] >=0) else 0, axis=1)
tss = ts["TotalScore"]
corr, _ = pearsonr(tss, el)
print(corr)
# Out:
# -0.5543429459008475

# %%
codes.query('S10_REsome == 0 and (S10_BEsome + S10_BCsome + S10_BLsome == 0) and (S10_REsome + S10_RLsome + S10_RCsome >=0)').shape
# Out:
# (330, 90)

# %%
330/883
# Out:
# 0.3737259343148358

# %%
ts = codes.query('S10_RCsome!=9')
el = ts.apply(lambda x: 1 if x['S10_REsome'] == 0 and (x['S10_BEsome'] + x['S10_BCsome'] + x['S10_BLsome'] == 0) and (x['S10_REsome'] + x['S10_RLsome'] + x['S10_RCsome'] >=0) else 0, axis=1)
tss = ts["TotalScore"]
corr, _ = pearsonr(tss, el)
print(corr)
# Out:
# -0.5333036693632988

# %%
codes.query('(S10_BCsome + S10_CEsome + S10_BCsome + S10_CEsome < 4) and (S10_BEsome + S10_BLsome + S10_BCsome >= 1) and (S10_REsome + S10_RLsome + S10_RCsome >=1) and (S10_BEsome + S10_BLsome + S10_BCsome + S10_REsome + S10_RLsome + S10_RCsome < 6)').shape
# Out:
# (153, 90)

# %%
153/883
# Out:
# 0.17327293318233294

# %%
ts = codes.query('S10_RCsome!=9')
el = ts.apply(lambda x: 1 if (x['S10_BCsome'] + x['S10_CEsome'] + x['S10_BCsome'] + x['S10_CEsome'] < 4) and (x['S10_BEsome'] + x['S10_BLsome'] + x['S10_BCsome'] >= 1) and (x['S10_REsome'] + x['S10_RLsome'] + x['S10_RCsome'] >=1) and (x['S10_BEsome'] + x['S10_BLsome'] + x['S10_BCsome'] + x['S10_REsome'] + x['S10_RLsome'] + x['S10_RCsome'] < 6) else 0, axis=1)
tss = ts["TotalScore"]
corr, _ = pearsonr(tss, el)
print(corr)
# Out:
# 0.01370285383792402

# %%
codes.query('(S10_BLsome + S10_RLsome < 2) and (S10_BEsome + S10_BLsome + S10_BCsome >= 1) and (S10_REsome + S10_RLsome + S10_RCsome >=1) and (S10_BEsome + S10_BLsome + S10_BCsome + S10_REsome + S10_RLsome + S10_RCsome < 6)').shape
# Out:
# (170, 90)

# %%
170/883
# Out:
# 0.19252548131370328

# %%
ts = codes.query('S10_RCsome!=9')
el = ts.apply(lambda x: 1 if (x['S10_BLsome'] + x['S10_RLsome'] < 2) and (x['S10_BEsome'] + x['S10_BLsome'] + x['S10_BCsome'] >= 1) and (x['S10_REsome'] + x['S10_RLsome'] + x['S10_RCsome'] >=1) and (x['S10_BEsome'] + x['S10_BLsome'] + x['S10_BCsome'] + x['S10_REsome'] + x['S10_RLsome'] + x['S10_RCsome'] < 6) else 0, axis=1)
tss = ts["TotalScore"]
corr, _ = pearsonr(tss, el)
print(corr)
# Out:
# 0.06348203235474625

# %%
codes.query('(S10_BEsome + S10_REsome < 2) and (S10_BEsome + S10_BLsome + S10_BCsome >= 1) and (S10_REsome + S10_RLsome + S10_RCsome >=1) and (S10_BEsome + S10_BLsome + S10_BCsome + S10_REsome + S10_RLsome + S10_RCsome < 6)').shape
# Out:
# (335, 90)

# %%
335/883
# Out:
# 0.3793884484711212

# %%
ts = codes.query('S10_RCsome!=9')
el = ts.apply(lambda x: 1 if (x['S10_BEsome'] + x['S10_REsome'] < 2) and (x['S10_BEsome'] + x['S10_BLsome'] + x['S10_BCsome'] >= 1) and (x['S10_REsome'] + x['S10_RLsome'] + x['S10_RCsome'] >=1) and (x['S10_BEsome'] + x['S10_BLsome'] + x['S10_BCsome'] + x['S10_REsome'] + x['S10_RLsome'] + x['S10_RCsome'] < 6) else 0, axis=1)
tss = ts["TotalScore"]
corr, _ = pearsonr(tss, el)
print(corr)
# Out:
# 0.334131929181697

# %%
codes.query('S10_AbEye + S10_AbLeaf + S08_raySeat < 2').shape
# Out:
# (400, 90)

# %%
codes.query('S10_AbEye != 9 and S08_raySeat != 9').shape
# Out:
# (880, 90)

# %%
400/880
# Out:
# 0.45454545454545453

# %%
ts = codes.query('S10_RCsome!=9 and S08_raySeat != 9')
el = ts.apply(lambda x: 1 if x['S10_AbEye'] + x['S10_AbLeaf'] + x['S08_raySeat'] < 2 else 0, axis=1)
tss = ts["TotalScore"]
corr, _ = pearsonr(tss, el)
print(corr)
# Out:
# -0.4896943827926615

# %%
codes.query('(S10_Remits + S10_Bemits == 0) or (S10_Remits ==0 and S08_emit ==1) or (S10_Bemits ==0 and S08_emit ==1)').shape
# Out:
# (451, 90)

# %%
451/880
# Out:
# 0.5125

# %%
ts = codes.query('S10_RCsome!=9 and S08_raySeat != 9')
el = ts.apply(lambda x: 1 if (x['S10_Remits'] + x['S10_Bemits'] == 0) or (x['S10_Remits'] ==0 and x['S08_emit'] ==1) or (x['S10_Bemits'] ==0 and x['S08_emit'] ==1) else 0, axis=1)
tss = ts["TotalScore"]
corr, _ = pearsonr(tss, el)
print(corr)
# Out:
# -0.4856685625719771

# %%
codes.query('(S10_RefChair + S08_rayScreen ==0)').shape
# Out:
# (136, 90)

# %%
136/880
# Out:
# 0.15454545454545454

# %%
ts = codes.query('S10_RCsome!=9 and S08_raySeat != 9')
el = ts.apply(lambda x: 1 if x['S10_RefChair'] + x['S08_rayScreen'] ==0 else 0, axis=1)
tss = ts["TotalScore"]
corr, _ = pearsonr(tss, el)
print(corr)
# Out:
# -0.3246021992150179
